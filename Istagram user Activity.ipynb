# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# import csv file
df = pd.read_csv(
    r'C:\Users\ADMIN\instagram_analysis_Project\Instagram_usage_lifestyle.csv',
    encoding='unicode_escape'
)

# %%
df.shape
# Out:
# (1020, 24)

# %%
df.head()
# Out:
#    ï»¿user_id   app_name  age      gender         country urban_rural  \
# 0           1  Instagram   51      Female           India       Rural
# 1           2  Instagram   64      Female  United Kingdom       Urban
# 2           3  Instagram   41      Female          Canada       Urban
# 3           4  Instagram   27  Non-binary     South Korea       Urban
# 4           5  Instagram   55        Male           India       Urban
#
#    income_level   employment_status relationship_status has_children  ...  \
# 0          High             Retired              Single           No  ...
# 1        Middle  Full-time employed            Divorced           No  ...
# 2        Middle             Student   In a relationship           No  ...
# 3        Middle          Unemployed   In a relationship           No  ...
# 4  Upper-middle  Full-time employed              Single           No  ...
#
#    perceived_stress_score  daily_steps_count likes_given_per_day  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ï»¿user_id                1020 non-null   int64
#  1   app_name                  1020 non-null   str
#  2   age                       1020 non-null   int64
#  3   gender                    1020 non-null   str
#  4   country                   1020 non-null   str
#  5   urban_rural               1020 non-null   str
#  6   income_level              1020 non-null   str
#  7   employment_status         1020 non-null   str
#  8   relationship_status       1020 non-null   str
#  9   has_children              1020 non-null   str
#  10  exercise_hours_per_week   1020 non-null   float64
#  11  sleep_hours_per_night     1020 non-null   float64
#  12  diet_quality              1020 non-null   str
#  13  smoking                   1020 non-null   str
# ...

# %%
pd.isnull(df)
# Out:
#       ï»¿user_id  app_name    age  gender  country  urban_rural  income_level  \
# 0          False     False  False   False    False        False         False
# 1          False     False  False   False    False        False         False
# 2          False     False  False   False    False        False         False
# 3          False     False  False   False    False        False         False
# 4          False     False  False   False    False        False         False
# ...          ...       ...    ...     ...      ...          ...           ...
# 1015       False     False  False   False    False        False         False
# 1016       False     False  False   False    False        False         False
# 1017       False     False  False   False    False        False         False
# 1018       False     False  False   False    False        False         False
# 1019       False     False  False   False    False        False         False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# ï»¿user_id                  0
# app_name                    0
# age                         0
# gender                      0
# country                     0
# urban_rural                 0
# income_level                0
# employment_status           0
# relationship_status         0
# has_children                0
# exercise_hours_per_week     0
# sleep_hours_per_night       0
# diet_quality                0
# smoking                     0
# perceived_stress_score      0
# daily_steps_count           0
# likes_given_per_day         0
# comments_written_per_day    0
# dms_sent_per_week           0
# followers_count             0
# following_count             0
# uses_premium_features       0
# account_creation_year       0
# privacy_setting_level       0
# dtype: int64

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
sns.histplot(df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['sleep_hours_per_night'], kde=True)
plt.title("Sleep Hours Per Night")
plt.show()

# %%
sns.histplot(df['daily_steps_count'], kde=True)
plt.title("Daily Steps Count")
plt.show()

# %%
sns.countplot(x='gender', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='country', data=df)
plt.xticks(rotation=45)
plt.title("Country Distribution")
plt.show()

# %%
# !pip install mysql-connector-python pandas
# Out:
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.5 MB 4.8 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/16.5 MB 6.4 MB/s eta 0:00:03
#    ---------- ----------------------------- 4.2/16.5 MB 6.8 MB/s eta 0:00:02
#    ------------ --------------------------- 5.2/16.5 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 5.8/16.5 MB 5.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 7.1/16.5 MB 5.6 MB/s eta 0:00:02
#    -------------------- ------------------- 8.7/16.5 MB 5.8 MB/s eta 0:00:02
#    ------------------------ --------------- 10.2/16.5 MB 5.9 MB/s eta 0:00:02
#    --------------------------- ------------ 11.5/16.5 MB 5.9 MB/s eta 0:00:01
#    ------------------------------- -------- 12.8/16.5 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.4/16.5 MB 6.1 MB/s eta 0:00:01
# ...

# %%
sns.scatterplot(x='sleep_hours_per_night', y='perceived_stress_score', data=df)
plt.title("Sleep vs Stress")
plt.show()

# %%
sns.scatterplot(x='exercise_hours_per_week', y='perceived_stress_score', data=df)
plt.title("Exercise vs Stress")
plt.show()

# %%
sns.countplot(x='uses_premium_features', data=df)
plt.title("Premium Features Usage")
plt.show()

# %%
sns.scatterplot(x='followers_count', y='following_count', data=df)
plt.title("Followers vs Following Relationship")
plt.show()

# %%
sns.histplot(df['comments_written_per_day'], kde=True)
plt.title("Comments Written Per Day")
plt.show()

# %%
sns.histplot(df['likes_given_per_day'], kde=True)
plt.title("Likes Given Per Day")
plt.show()

# %%
# !pip install sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 6.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.2 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/3 [pymysql]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
from sqlalchemy import create_engine

engine=create_engine(
    "mysql+pymysql://root:system@localhost/insta_social_media"
)

# %%
table_name = "insta_Analysis"

df.to_sql(
    name=table_name,
    con=engine,
    if_exists="replace",   # PostgreSQL सारखंच
    index=False
)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10652\3201096263.py:3: UserWarning: The provided table name 'insta_Analysis' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql(
# 1020
